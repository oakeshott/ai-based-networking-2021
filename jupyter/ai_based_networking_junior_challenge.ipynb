# %% [markdown]
# <a href="https://colab.research.google.com/github/oakeshott/ai-based-networking-2021/blob/master/jupyter/ai_based_networking_junior_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI-based Networking ジュニアチャレンジ サンプルプログラム

# %%
# !pip install torch pandas numpy joblib tqdm sklearn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.2)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
import json
import glob
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import pandas as pd
import numpy as np
import joblib
from tqdm.notebook import tqdm
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
class Transformer:
    def __init__(self, is_train=False):
        self.transformer = dict()
        self.is_train = is_train
        if not self.is_train:
            self.transformer = self.load()

    def __call__(self, df, metric):
        if self.is_train:
            return self.fit_transform(df, metric)
        else:
            df[:] = self.transformer[metric].transform(df)
            return df

    def inverse_transform(self, scaled, metric):
        return self.transformer[metric].inverse_transform(scaled)

    def fit_transform(self, df, metric):
        self.transformer[metric] = MinMaxScaler()
        df = self.transformer[metric].fit_transform(df)
        self.dump()
        return df

    def dump(self, filename='/tmp/transformer.bin'):
        with open(filename, 'wb') as f:
            joblib.dump(self.transformer, f)

    def load(self, filename='/tmp/transformer.bin'):
        with open(filename, 'rb') as f:
            data = joblib.load(f)
        return data

# %%
class SimilarityDataset(Dataset):
    def __init__(self, path, sequence_length, device=None, transform=None, is_train=True):
        self.sequence_length = sequence_length
        self.transform = transform

        if device is None: self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        else:
            self.device = device

        metrics        = ["psnr", "ssim"]
        target_metrics = ["throughput", "loss_rate"]

        self.input_dim  = len(metrics)
        self.target_dim = len(target_metrics)

        if is_train:
            files = glob.glob(os.path.join(path, "*.json"))
            df = self.read_files(files, self.sequence_length)
        else:
            df = self.read_file(path, sequence_length)

        if self.transform:
            for metric in metrics:
                df[[metric]] = self.transform(df[[metric]], metric)

        df.index = df[["video_type", "throughput", "loss_rate", "interval"]]
        indices = df[["video_type", "throughput", "loss_rate", "interval"]].index.unique()
        grouped_df = df.groupby(["video_type", "throughput", "loss_rate", "interval"])

        self.data = []
        self.target = []
        for index in tqdm(indices):
            series = grouped_df.get_group(index)
            if len(series) < self.sequence_length:
                continue
            video_type, throughput, loss_rate, interval = index
            self.data.append(series[metrics].values)
            self.target.append([throughput, loss_rate])

    def __getitem__(self, idx):
        ret = torch.tensor(self.data[idx], dtype=torch.float64, device=self.device)
        trg = torch.tensor(self.target[idx], dtype=torch.float64, device=self.device)
        return ret, trg

    def __len__(self):
        return len(self.data)

    def read_files(self, files, sequence_length):
        li_df = []
        for filename in tqdm(files):
            df = self.read_file(filename, sequence_length)
            li_df.append(df)
        df = pd.concat(li_df)
        return df

    def read_file(self, filename, sequence_length):
        with open(filename) as f:
            d = json.load(f)
        df = pd.DataFrame.from_dict(d)
        df["interval"] = df["frame_index"] // sequence_length
        df = df.sort_values("frame_index")
        return df

# %%
def collate_fn(batch):
    data, targets = list(zip(*batch))
    data    = torch.stack(data)
    targets = torch.stack(targets)
    return data, targets

def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)

# %%
class NetworkStateEstimationFromVideoStreaming(nn.Module):
    def __init__(self, input_dim, target_dim, sequence_length, hidden_dim):
        super(NetworkStateEstimationFromVideoStreaming, self).__init__()
        self.input_dim       = input_dim
        self.target_dim      = target_dim
        self.sequence_length = sequence_length
        self.hidden_dim      = hidden_dim

        self.fc1     = nn.Linear(self.input_dim * self.sequence_length, self.hidden_dim)
        self.fc2     = nn.Linear(self.hidden_dim, self.target_dim)
        self.relu    = nn.ReLU()

    def forward(self, x):
        x = x.view(-1, self.input_dim * self.sequence_length)
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
def train(input_dir="/content/drive/MyDrive/similarity_measures/train", model_dir="/content/models", seed=1, fold=4, batchsize=32, log_seq=1):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    transformer = Transformer(is_train=True)

    similarity_dir = input_dir
    model_dir      = model_dir
    seed           = seed
    fold_split     = fold
    batch_size     = batchsize

    set_seed(seed)

    sequence_length = 1000
    hidden_dim      = 128
    num_layers      = 2
    max_epoches     = 1000
    log_seq         = log_seq

    train_and_valid_dataset = SimilarityDataset(
            path=similarity_dir,
            sequence_length=sequence_length,
            device=device,
            transform=None
            )
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    X = train_and_valid_dataset.data
    Y = train_and_valid_dataset.target
    skf = KFold(n_splits=fold_split, shuffle=True, random_state=seed)
    for i, (train_idx, valid_idx) in enumerate(skf.split(X, Y)):
        train_dataset = Subset(train_and_valid_dataset, train_idx)
        valid_dataset = Subset(train_and_valid_dataset, valid_idx)
        train_size = len(train_dataset)
        valid_size = len(valid_dataset)
        print(f'fold : {i+1} train dataset size : {train_size} valid dataset size: {valid_size}')

        train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        valid_dataloader = DataLoader(valid_dataset, batch_size=valid_size, shuffle=True, collate_fn=collate_fn)

        input_dim  = train_and_valid_dataset.input_dim
        target_dim = train_and_valid_dataset.target_dim

        model = NetworkStateEstimationFromVideoStreaming(input_dim, target_dim, sequence_length, hidden_dim).to(device)

        loss_function = nn.SmoothL1Loss()
        l1loss_function = nn.L1Loss()

        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        for epoch in range(1, max_epoches + 1):
            train_loss = 0
            for train_inputs, train_targets in train_dataloader:

                train_inputs  = train_inputs.float()
                train_targets = train_targets.float()
                train_inputs  = train_inputs.to(device)
                train_targets = train_targets.to(device)

                optimizer.zero_grad()

                train_scores = model(train_inputs)

                loss = loss_function(train_scores, train_targets)
                loss.backward()
                optimizer.step()

                train_loss += loss.item()
            train_loss /= len(train_dataloader)

            with torch.no_grad():
                valid_inputs, valid_targets = iter(valid_dataloader).next()

                valid_inputs  = valid_inputs.float()
                valid_targets = valid_targets.float()
                valid_inputs  = valid_inputs.to(device)
                valid_targets = valid_targets.to(device)

                valid_scores = model(valid_inputs)

                loss = loss_function(valid_scores, valid_targets)
                valid_loss = loss.item() / len(valid_dataloader)

                val_scores  = valid_scores.to('cpu').detach().numpy().astype(np.float32)
                val_targets = valid_targets.to('cpu').detach().numpy().astype(np.float32)
                throughput_scores = valid_scores[:, 0]
                loss_rate_scores  = valid_scores[:, 1]
                throughput_targets = valid_targets[:, 0]
                loss_rate_targets  = valid_targets[:, 1]

                throughput_loss, loss_rate_loss = (l1loss_function(throughput_scores, throughput_targets).item(), l1loss_function(loss_rate_scores, loss_rate_targets).item())

            if epoch < 10 or epoch % log_seq == 0:
                print(f"Epoch: [{epoch}/{max_epoches}] train/valid loss: {train_loss:.4f} / {valid_loss:.4f} throughput/loss rate: {throughput_loss:.4f} / {loss_rate_loss:.4f}")

            if epoch % 500 == 0:
                torch.save(model.state_dict(), f"{model_dir}/fold{i + 1}_{epoch}.mdl")

# %%
def test(input_path="/content/drive/MyDrive/similarity_measures/test/issue/similarity_0.json", model_path="/content/models/fold1_1000.mdl", seed=1):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    similarity_path = input_path
    model_path     = model_path
    seed           = seed

    set_seed(seed)

    sequence_length = 1000
    hidden_dim      = 128
    num_layers      = 2
    max_epoches     = 1000

    test_dataset = SimilarityDataset(
            path=similarity_path,
            sequence_length=sequence_length,
            device=device,
            transform=None,
            is_train=False
            )

    test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=True, collate_fn=collate_fn)

    input_dim  = test_dataset.input_dim
    target_dim = test_dataset.target_dim

    model = NetworkStateEstimationFromVideoStreaming(input_dim, target_dim, sequence_length, hidden_dim).to(device)
    model.load_state_dict(torch.load(model_path))

    loss_function = nn.L1Loss()

    with torch.no_grad():
        test_inputs, test_targets = iter(test_dataloader).next()
        test_inputs  = test_inputs.float()
        test_targets = test_targets.float()

        test_scores = model(test_inputs)
        test_targets = test_targets.to(device)
        test_loss   = loss_function(test_scores, test_targets)

        throughput_scores = test_scores[:, 0]
        loss_rate_scores  = test_scores[:, 1]
        throughput_targets = test_targets[:, 0]
        loss_rate_targets  = test_targets[:, 1]

        throughput = throughput_scores.mean()
        loss_rate  = loss_rate_scores.mean()

        throughput_loss, loss_rate_loss = (loss_function(throughput_scores, throughput_targets).item(), loss_function(loss_rate_scores, loss_rate_targets).item())
        print(f"model: {model_path} throughput / loss rate {throughput} / {loss_rate} throughput loss/ loss rate loss: {throughput_loss:.4f} / {loss_rate_loss:.4f}")

# %%
train(log_seq=50)
# Out:
#   0%|          | 0/240 [00:00<?, ?it/s]
#   0%|          | 0/1560 [00:00<?, ?it/s]
# fold : 1 train dataset size : 990 valid dataset size: 330
# Epoch: [1/1000] train/valid loss: 419.4211 / 213.1811 throughput/loss rate: 420.4278 / 6.9337
# Epoch: [2/1000] train/valid loss: 206.0680 / 195.4487 throughput/loss rate: 382.0102 / 9.8871
# Epoch: [3/1000] train/valid loss: 188.9131 / 180.6811 throughput/loss rate: 356.4599 / 5.9023
# Epoch: [4/1000] train/valid loss: 181.9957 / 173.7788 throughput/loss rate: 343.2201 / 5.3375
# Epoch: [5/1000] train/valid loss: 175.8636 / 167.3287 throughput/loss rate: 333.5474 / 2.0531
# Epoch: [6/1000] train/valid loss: 171.3365 / 165.2188 throughput/loss rate: 325.8324 / 5.6052
# Epoch: [7/1000] train/valid loss: 167.2061 / 160.0894 throughput/loss rate: 319.0791 / 2.0956
# Epoch: [8/1000] train/valid loss: 162.3053 / 159.0345 throughput/loss rate: 316.2848 / 2.7769
# Epoch: [9/1000] train/valid loss: 161.2137 / 155.8512 throughput/loss rate: 311.5449 / 1.0777
# Epoch: [50/1000] train/valid loss: 104.1393 / 117.8748 throughput/loss rate: 235.9533 / 0.6780
# Epoch: [100/1000] train/valid loss: 83.7669 / 86.0739 throughput/loss rate: 172.4749 / 0.4519
# Epoch: [150/1000] train/valid loss: 69.3262 / 74.3031 throughput/loss rate: 149.0369 / 0.2608
# Epoch: [200/1000] train/valid loss: 61.8242 / 78.9276 throughput/loss rate: 158.3244 / 0.2011
# Epoch: [250/1000] train/valid loss: 59.5260 / 69.1662 throughput/loss rate: 138.1909 / 1.1281
# Epoch: [300/1000] train/valid loss: 57.4177 / 72.8359 throughput/loss rate: 146.0454 / 0.4626
# Epoch: [350/1000] train/valid loss: 54.5345 / 65.6762 throughput/loss rate: 131.8033 / 0.2678
# Epoch: [400/1000] train/valid loss: 56.2193 / 70.6719 throughput/loss rate: 141.4564 / 0.8164
# Epoch: [450/1000] train/valid loss: 52.3302 / 61.9382 throughput/loss rate: 124.3489 / 0.1901
# Epoch: [500/1000] train/valid loss: 52.3403 / 70.3659 throughput/loss rate: 141.2207 / 0.1236
# Epoch: [550/1000] train/valid loss: 51.5203 / 61.2770 throughput/loss rate: 123.0307 / 0.1863
# Epoch: [600/1000] train/valid loss: 47.5778 / 60.3878 throughput/loss rate: 121.2639 / 0.1107
# Epoch: [650/1000] train/valid loss: 46.9328 / 58.9836 throughput/loss rate: 118.3342 / 0.4757
# Epoch: [700/1000] train/valid loss: 47.8537 / 59.8148 throughput/loss rate: 120.1220 / 0.1008
# Epoch: [750/1000] train/valid loss: 46.4636 / 59.7754 throughput/loss rate: 120.0382 / 0.1321
# Epoch: [800/1000] train/valid loss: 49.4633 / 67.6055 throughput/loss rate: 135.7009 / 0.1125
# Epoch: [850/1000] train/valid loss: 43.3638 / 63.1682 throughput/loss rate: 126.8295 / 0.0967
# Epoch: [900/1000] train/valid loss: 46.0310 / 61.8071 throughput/loss rate: 122.4018 / 2.2122
# Epoch: [950/1000] train/valid loss: 42.2078 / 58.4564 throughput/loss rate: 117.4060 / 0.0896
# Epoch: [1000/1000] train/valid loss: 42.9794 / 66.7065 throughput/loss rate: 133.9049 / 0.0895
# fold : 2 train dataset size : 990 valid dataset size: 330
# Epoch: [1/1000] train/valid loss: 386.2743 / 256.7626 throughput/loss rate: 499.8639 / 14.6612
# Epoch: [2/1000] train/valid loss: 204.0463 / 199.9056 throughput/loss rate: 395.1620 / 5.6413
# Epoch: [3/1000] train/valid loss: 183.0813 / 190.7522 throughput/loss rate: 376.1497 / 6.3547
# Epoch: [4/1000] train/valid loss: 176.3332 / 183.4474 throughput/loss rate: 365.5776 / 2.2954
# Epoch: [5/1000] train/valid loss: 173.3208 / 180.2682 throughput/loss rate: 359.9471 / 1.5595
# Epoch: [6/1000] train/valid loss: 168.2894 / 175.2672 throughput/loss rate: 345.4029 / 6.1312
# Epoch: [7/1000] train/valid loss: 162.4005 / 180.0296 throughput/loss rate: 356.4698 / 4.5893
# Epoch: [8/1000] train/valid loss: 163.3919 / 169.1763 throughput/loss rate: 338.1837 / 1.0235
# Epoch: [9/1000] train/valid loss: 159.4149 / 169.6522 throughput/loss rate: 332.9026 / 7.4007
# Epoch: [50/1000] train/valid loss: 114.1649 / 114.0664 throughput/loss rate: 225.9348 / 3.1938
# Epoch: [100/1000] train/valid loss: 82.8594 / 88.0513 throughput/loss rate: 176.4970 / 0.3093
# Epoch: [150/1000] train/valid loss: 66.2533 / 76.3018 throughput/loss rate: 152.9442 / 0.4751
# Epoch: [200/1000] train/valid loss: 63.9615 / 70.3902 throughput/loss rate: 141.2581 / 0.1528
# Epoch: [250/1000] train/valid loss: 59.1943 / 77.7554 throughput/loss rate: 155.3865 / 1.1110
# Epoch: [300/1000] train/valid loss: 53.0375 / 67.7368 throughput/loss rate: 135.9466 / 0.1831
# Epoch: [350/1000] train/valid loss: 53.3895 / 68.8345 throughput/loss rate: 138.1504 / 0.1402
# Epoch: [400/1000] train/valid loss: 58.8599 / 72.1611 throughput/loss rate: 144.8039 / 0.1375
# Epoch: [450/1000] train/valid loss: 48.6062 / 66.4217 throughput/loss rate: 133.3350 / 0.1009
# Epoch: [500/1000] train/valid loss: 49.3834 / 66.9088 throughput/loss rate: 134.3106 / 0.0850
# Epoch: [550/1000] train/valid loss: 47.9031 / 67.7531 throughput/loss rate: 135.9730 / 0.2268
# Epoch: [600/1000] train/valid loss: 45.2814 / 65.0730 throughput/loss rate: 130.6364 / 0.1112
# Epoch: [650/1000] train/valid loss: 47.2953 / 64.4817 throughput/loss rate: 129.4365 / 0.2004
# Epoch: [700/1000] train/valid loss: 42.7209 / 63.7085 throughput/loss rate: 127.9001 / 0.1639
# Epoch: [750/1000] train/valid loss: 44.5791 / 67.3646 throughput/loss rate: 135.2189 / 0.1065
# Epoch: [800/1000] train/valid loss: 43.7045 / 67.4383 throughput/loss rate: 135.3564 / 0.1721
# Epoch: [850/1000] train/valid loss: 46.5309 / 77.0676 throughput/loss rate: 154.6232 / 0.1000
# Epoch: [900/1000] train/valid loss: 41.1609 / 61.6727 throughput/loss rate: 123.8379 / 0.0828
# Epoch: [950/1000] train/valid loss: 39.4555 / 61.6574 throughput/loss rate: 123.8092 / 0.0696
# Epoch: [1000/1000] train/valid loss: 43.9269 / 67.4910 throughput/loss rate: 135.4758 / 0.0869
# fold : 3 train dataset size : 990 valid dataset size: 330
# Epoch: [1/1000] train/valid loss: 404.6223 / 218.4911 throughput/loss rate: 417.2457 / 20.7366
# Epoch: [2/1000] train/valid loss: 204.0384 / 174.0810 throughput/loss rate: 343.1523 / 6.0058
# Epoch: [3/1000] train/valid loss: 188.6485 / 166.0023 throughput/loss rate: 331.0477 / 1.9068
# Epoch: [4/1000] train/valid loss: 182.6023 / 166.8268 throughput/loss rate: 333.0739 / 1.5333
# Epoch: [5/1000] train/valid loss: 177.1968 / 160.9239 throughput/loss rate: 317.4451 / 5.4026
# Epoch: [6/1000] train/valid loss: 170.4388 / 157.6721 throughput/loss rate: 313.7082 / 2.6326
# Epoch: [7/1000] train/valid loss: 169.0400 / 156.7126 throughput/loss rate: 311.7270 / 2.6898
# Epoch: [8/1000] train/valid loss: 166.5896 / 154.8190 throughput/loss rate: 309.1058 / 1.4909
# Epoch: [9/1000] train/valid loss: 162.6966 / 159.9168 throughput/loss rate: 305.7838 / 15.0499
# Epoch: [50/1000] train/valid loss: 103.9995 / 104.4047 throughput/loss rate: 208.3983 / 1.3880
# Epoch: [100/1000] train/valid loss: 81.0548 / 85.2019 throughput/loss rate: 169.7637 / 1.6254
# Epoch: [150/1000] train/valid loss: 66.7991 / 79.1770 throughput/loss rate: 158.8151 / 0.2355
# Epoch: [200/1000] train/valid loss: 61.6044 / 70.0417 throughput/loss rate: 140.5173 / 0.3056
# Epoch: [250/1000] train/valid loss: 60.8913 / 70.3828 throughput/loss rate: 141.1956 / 0.2980
# Epoch: [300/1000] train/valid loss: 55.6144 / 66.9415 throughput/loss rate: 134.3679 / 0.1268
# Epoch: [350/1000] train/valid loss: 54.0791 / 75.2971 throughput/loss rate: 150.8344 / 0.6440
# Epoch: [400/1000] train/valid loss: 51.4456 / 67.7623 throughput/loss rate: 135.9833 / 0.2294
# Epoch: [450/1000] train/valid loss: 51.1363 / 65.4446 throughput/loss rate: 131.3684 / 0.1483
# Epoch: [500/1000] train/valid loss: 48.2554 / 63.6068 throughput/loss rate: 127.6650 / 0.2691
# Epoch: [550/1000] train/valid loss: 44.3679 / 63.3572 throughput/loss rate: 127.2026 / 0.1125
# Epoch: [600/1000] train/valid loss: 44.4930 / 64.8402 throughput/loss rate: 130.1443 / 0.2360
# Epoch: [650/1000] train/valid loss: 44.3309 / 66.2643 throughput/loss rate: 133.0038 / 0.1862
# Epoch: [700/1000] train/valid loss: 47.0202 / 62.7837 throughput/loss rate: 126.0525 / 0.1166
# Epoch: [750/1000] train/valid loss: 47.0634 / 65.9002 throughput/loss rate: 132.1413 / 0.5326
# Epoch: [800/1000] train/valid loss: 41.7806 / 63.0922 throughput/loss rate: 126.6621 / 0.1803
# Epoch: [850/1000] train/valid loss: 44.8892 / 62.4192 throughput/loss rate: 125.3333 / 0.0751
# Epoch: [900/1000] train/valid loss: 40.1453 / 62.5297 throughput/loss rate: 125.5538 / 0.0749
# Epoch: [950/1000] train/valid loss: 44.4207 / 69.1932 throughput/loss rate: 138.6577 / 0.6510
# Epoch: [1000/1000] train/valid loss: 38.7970 / 62.6690 throughput/loss rate: 125.8312 / 0.0939
# fold : 4 train dataset size : 990 valid dataset size: 330
# Epoch: [1/1000] train/valid loss: 382.0655 / 241.0498 throughput/loss rate: 477.2876 / 5.8120
# Epoch: [2/1000] train/valid loss: 195.9740 / 199.7034 throughput/loss rate: 398.2668 / 2.1383
# Epoch: [3/1000] train/valid loss: 181.4830 / 189.1292 throughput/loss rate: 378.5974 / 0.4762
# Epoch: [4/1000] train/valid loss: 174.4448 / 182.5535 throughput/loss rate: 365.3861 / 0.5585
# Epoch: [5/1000] train/valid loss: 171.1371 / 179.6922 throughput/loss rate: 358.1517 / 2.2269
# Epoch: [6/1000] train/valid loss: 167.5948 / 172.7847 throughput/loss rate: 344.8554 / 1.6747
# Epoch: [7/1000] train/valid loss: 162.2258 / 172.9892 throughput/loss rate: 346.2039 / 0.6086
# Epoch: [8/1000] train/valid loss: 161.6366 / 166.4077 throughput/loss rate: 333.0807 / 0.5718
# Epoch: [9/1000] train/valid loss: 158.4404 / 163.6207 throughput/loss rate: 326.2458 / 1.9790
# Epoch: [50/1000] train/valid loss: 109.0946 / 121.3044 throughput/loss rate: 241.7146 / 1.8914
# Epoch: [100/1000] train/valid loss: 84.8903 / 92.7487 throughput/loss rate: 185.9789 / 0.1443
# Epoch: [150/1000] train/valid loss: 71.9329 / 83.5096 throughput/loss rate: 167.4698 / 0.2395
# Epoch: [200/1000] train/valid loss: 68.6952 / 72.9213 throughput/loss rate: 146.2548 / 0.3667
# Epoch: [250/1000] train/valid loss: 63.6173 / 70.7525 throughput/loss rate: 141.9957 / 0.0903
# Epoch: [300/1000] train/valid loss: 58.3818 / 65.3030 throughput/loss rate: 131.0867 / 0.1491
# Epoch: [350/1000] train/valid loss: 60.7744 / 63.1109 throughput/loss rate: 126.6886 / 0.2267
# Epoch: [400/1000] train/valid loss: 56.3551 / 62.7919 throughput/loss rate: 125.8287 / 0.6923
# Epoch: [450/1000] train/valid loss: 56.1786 / 73.5810 throughput/loss rate: 147.6504 / 0.1207
# Epoch: [500/1000] train/valid loss: 53.2089 / 66.7505 throughput/loss rate: 133.9139 / 0.3862
# Epoch: [550/1000] train/valid loss: 50.5468 / 62.4391 throughput/loss rate: 125.3635 / 0.1230
# Epoch: [600/1000] train/valid loss: 47.9349 / 62.7723 throughput/loss rate: 126.0360 / 0.1095
# Epoch: [650/1000] train/valid loss: 48.9150 / 60.1215 throughput/loss rate: 120.7329 / 0.1139
# Epoch: [700/1000] train/valid loss: 50.8484 / 60.3964 throughput/loss rate: 121.2780 / 0.1477
# Epoch: [750/1000] train/valid loss: 49.1435 / 63.1693 throughput/loss rate: 126.8274 / 0.1171
# Epoch: [800/1000] train/valid loss: 43.7787 / 64.3619 throughput/loss rate: 129.2116 / 0.1246
# Epoch: [850/1000] train/valid loss: 47.5010 / 61.4263 throughput/loss rate: 123.2692 / 0.3790
# Epoch: [900/1000] train/valid loss: 46.3485 / 60.2330 throughput/loss rate: 120.9569 / 0.0940
# Epoch: [950/1000] train/valid loss: 43.7240 / 58.5838 throughput/loss rate: 117.6422 / 0.2053
# Epoch: [1000/1000] train/valid loss: 43.8435 / 57.7423 throughput/loss rate: 115.9797 / 0.0735

# %%
test(input_path="/content/drive/MyDrive/similarity_measures/test/issue/similarity_0.json")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# model: /content/models/fold1_1000.mdl throughput / loss rate 1878.5208740234375 / 0.08475210517644882 throughput loss/ loss rate loss: 1878.5209 / 0.1222
